# %%
# Here we import all the necessary libraries to generate NMR spectra
import matplotlib.pyplot as plt
from nmrsim import Multiplet
from random import randint, uniform
import pandas

# %%
# Function to generate NMR signals based on input argument of spectrometer freq
def NMR_Signal_Generator(spectrometer_frequencies):
    # Assigning number of protons defined by peak integral
    integral = randint(1,4)
    #Assigning the linewidth of an NMR peak in the spectrum
    linewidth_hz = 2
    # Randomly return a floating point chemical shift assignment
    chemical_shift = uniform(0.5,9)
    # Randomly return a floating point coupling (J coupling) frequency
    coupling = uniform(3,15)
    # Randomly select a multiplicity (peak splitting)
    multiplicity = randint(0,5)
    # Generate a list of NMR signals using the Multiplet function of nmrsim
    signals_list = [(Multiplet(chemical_shift * frequency, integral, 
                               [(coupling,multiplicity)], linewidth_hz)) for frequency in spectrometer_frequencies]
    return signals_list

# %%
def create_random_spectra(num_peaks):
    # Assigns desired NMR frequencies to a list
    spectrometer_frequencies = [400,60]
    # Creates blank dataframe with desired NMR frequencies column
    spectral_data = pandas.DataFrame(columns=['400MHz', '60MHz'])
    
    # Generates NMR Signals from NMRSIM using established list, generates
    # spectra and puts them in spectral_data frame
    for i in range(0,num_peaks):
        signals_list = NMR_Signal_Generator(spectrometer_frequencies)
        spectral_data.loc[len(spectral_data)] = signals_list

    # Defines spectrum object, from Multiplet class
    # Multiplets taken from spectral_data frequency df
    spectrum_400MHz = Multiplet(0,0.5,[],2) 
    for multiplet in spectral_data['400MHz']:
        spectrum_400MHz += multiplet
        
    # Process repeated for other frequency
    spectrum_60MHz = Multiplet(0,0.5,[],2)
    for multiplet in spectral_data['60MHz']:
        spectrum_60MHz += multiplet
    
    # Normalize the spectrometer frequencies and have n number of points on plots
    spectrum_400MHz.vmin = -0.5 * spectrometer_frequencies[0]
    spectrum_400MHz.vmax = 10.5 * spectrometer_frequencies[0]
    x_400, y_400 = spectrum_400MHz.lineshape(points=5500)

    spectrum_60MHz.vmin = -0.5 * spectrometer_frequencies[1]
    spectrum_60MHz.vmax = 10.5 * spectrometer_frequencies[1]
    x_60, y_60 = spectrum_60MHz.lineshape(points=5500)

    return x_400, y_400, x_60, y_60

# %%
def write_nmr_spectra(index, num_peaks, x_400, y_400, x_60, y_60):
    # Saving data to file
    sf = [400,60]
    x_ppm_400 = x_400/sf[0]
    x_ppm_60 = x_60/sf[1]
    spectral_data = pandas.DataFrame(columns=['400MHz_ppm','400MHz_intensity', '60MHz_ppm','60MHz_intensity'])
    spectral_data['400MHz_ppm'] = x_ppm_400
    spectral_data['400MHz_intensity'] = y_400
    spectral_data['60MHz_ppm'] = x_ppm_60
    spectral_data['60MHz_intensity'] = y_60
    filename="NMRfiles_Test/400MHz/"+"spectral_data_"+ str(num_peaks).zfill(2)+ "_" +str(index).zfill(5)+".csv"
    print(filename)
    spectral_data.to_csv(filename)

# %%
import time

# %%
# num_peaks = Number of Peaks that you want in your spectra
# j = how many spectra do you want.
x = time.time()

for j in range (0,200):
    num_peaks = randint(5,16)
    #print(num_peaks)
    x_400, y_400, x_60, y_60 = create_random_spectra(num_peaks)
    write_nmr_spectra(j, num_peaks, x_400, y_400, x_60, y_60)

print(time.time()-x)
# Out:
# NMRfiles_Test/400MHz/spectral_data_11_00000.csv
# NMRfiles_Test/400MHz/spectral_data_12_00001.csv
# NMRfiles_Test/400MHz/spectral_data_11_00002.csv
# NMRfiles_Test/400MHz/spectral_data_16_00003.csv
# NMRfiles_Test/400MHz/spectral_data_06_00004.csv
# NMRfiles_Test/400MHz/spectral_data_11_00005.csv
# NMRfiles_Test/400MHz/spectral_data_06_00006.csv
# NMRfiles_Test/400MHz/spectral_data_08_00007.csv
# NMRfiles_Test/400MHz/spectral_data_12_00008.csv
# NMRfiles_Test/400MHz/spectral_data_08_00009.csv
# NMRfiles_Test/400MHz/spectral_data_12_00010.csv
# NMRfiles_Test/400MHz/spectral_data_13_00011.csv
# NMRfiles_Test/400MHz/spectral_data_15_00012.csv
# NMRfiles_Test/400MHz/spectral_data_16_00013.csv
# NMRfiles_Test/400MHz/spectral_data_16_00014.csv
# NMRfiles_Test/400MHz/spectral_data_16_00015.csv
# NMRfiles_Test/400MHz/spectral_data_05_00016.csv
# NMRfiles_Test/400MHz/spectral_data_13_00017.csv
# NMRfiles_Test/400MHz/spectral_data_15_00018.csv
# NMRfiles_Test/400MHz/spectral_data_05_00019.csv
# NMRfiles_Test/400MHz/spectral_data_08_00020.csv
# NMRfiles_Test/400MHz/spectral_data_16_00021.csv
# NMRfiles_Test/400MHz/spectral_data_05_00022.csv
# NMRfiles_Test/400MHz/spectral_data_06_00023.csv
# NMRfiles_Test/400MHz/spectral_data_05_00024.csv
# NMRfiles_Test/400MHz/spectral_data_15_00025.csv
# NMRfiles_Test/400MHz/spectral_data_11_00026.csv
# NMRfiles_Test/400MHz/spectral_data_06_00027.csv
# NMRfiles_Test/400MHz/spectral_data_07_00028.csv
# NMRfiles_Test/400MHz/spectral_data_10_00029.csv
# NMRfiles_Test/400MHz/spectral_data_11_00030.csv
# NMRfiles_Test/400MHz/spectral_data_06_00031.csv
# NMRfiles_Test/400MHz/spectral_data_10_00032.csv
# NMRfiles_Test/400MHz/spectral_data_13_00033.csv
# NMRfiles_Test/400MHz/spectral_data_10_00034.csv
# NMRfiles_Test/400MHz/spectral_data_12_00035.csv
# NMRfiles_Test/400MHz/spectral_data_14_00036.csv
# NMRfiles_Test/400MHz/spectral_data_10_00037.csv
# NMRfiles_Test/400MHz/spectral_data_07_00038.csv
# NMRfiles_Test/400MHz/spectral_data_08_00039.csv
# NMRfiles_Test/400MHz/spectral_data_12_00040.csv
# NMRfiles_Test/400MHz/spectral_data_13_00041.csv
# NMRfiles_Test/400MHz/spectral_data_12_00042.csv
# NMRfiles_Test/400MHz/spectral_data_06_00043.csv
# NMRfiles_Test/400MHz/spectral_data_12_00044.csv
# NMRfiles_Test/400MHz/spectral_data_11_00045.csv
# NMRfiles_Test/400MHz/spectral_data_08_00046.csv
# NMRfiles_Test/400MHz/spectral_data_12_00047.csv
# NMRfiles_Test/400MHz/spectral_data_10_00048.csv
# NMRfiles_Test/400MHz/spectral_data_05_00049.csv
# NMRfiles_Test/400MHz/spectral_data_06_00050.csv
# NMRfiles_Test/400MHz/spectral_data_06_00051.csv
# NMRfiles_Test/400MHz/spectral_data_05_00052.csv
# NMRfiles_Test/400MHz/spectral_data_11_00053.csv
# NMRfiles_Test/400MHz/spectral_data_11_00054.csv
# NMRfiles_Test/400MHz/spectral_data_10_00055.csv
# NMRfiles_Test/400MHz/spectral_data_12_00056.csv
# NMRfiles_Test/400MHz/spectral_data_06_00057.csv
# NMRfiles_Test/400MHz/spectral_data_07_00058.csv
# NMRfiles_Test/400MHz/spectral_data_06_00059.csv
# NMRfiles_Test/400MHz/spectral_data_15_00060.csv
# NMRfiles_Test/400MHz/spectral_data_12_00061.csv
# NMRfiles_Test/400MHz/spectral_data_10_00062.csv
# NMRfiles_Test/400MHz/spectral_data_12_00063.csv
# NMRfiles_Test/400MHz/spectral_data_14_00064.csv
# NMRfiles_Test/400MHz/spectral_data_12_00065.csv
# NMRfiles_Test/400MHz/spectral_data_14_00066.csv
# NMRfiles_Test/400MHz/spectral_data_10_00067.csv
# NMRfiles_Test/400MHz/spectral_data_07_00068.csv
# NMRfiles_Test/400MHz/spectral_data_12_00069.csv
# NMRfiles_Test/400MHz/spectral_data_08_00070.csv
# NMRfiles_Test/400MHz/spectral_data_06_00071.csv
# NMRfiles_Test/400MHz/spectral_data_10_00072.csv
# NMRfiles_Test/400MHz/spectral_data_08_00073.csv
# NMRfiles_Test/400MHz/spectral_data_10_00074.csv
# NMRfiles_Test/400MHz/spectral_data_11_00075.csv
# NMRfiles_Test/400MHz/spectral_data_09_00076.csv
# NMRfiles_Test/400MHz/spectral_data_16_00077.csv
# NMRfiles_Test/400MHz/spectral_data_05_00078.csv
# NMRfiles_Test/400MHz/spectral_data_05_00079.csv
# NMRfiles_Test/400MHz/spectral_data_14_00080.csv
# NMRfiles_Test/400MHz/spectral_data_15_00081.csv
# NMRfiles_Test/400MHz/spectral_data_11_00082.csv
# NMRfiles_Test/400MHz/spectral_data_11_00083.csv
# NMRfiles_Test/400MHz/spectral_data_14_00084.csv
# NMRfiles_Test/400MHz/spectral_data_05_00085.csv
# NMRfiles_Test/400MHz/spectral_data_07_00086.csv
# NMRfiles_Test/400MHz/spectral_data_12_00087.csv
# NMRfiles_Test/400MHz/spectral_data_10_00088.csv
# NMRfiles_Test/400MHz/spectral_data_11_00089.csv
# NMRfiles_Test/400MHz/spectral_data_12_00090.csv
# NMRfiles_Test/400MHz/spectral_data_15_00091.csv
# NMRfiles_Test/400MHz/spectral_data_05_00092.csv
# NMRfiles_Test/400MHz/spectral_data_12_00093.csv
# NMRfiles_Test/400MHz/spectral_data_12_00094.csv
# NMRfiles_Test/400MHz/spectral_data_07_00095.csv
# NMRfiles_Test/400MHz/spectral_data_15_00096.csv
# NMRfiles_Test/400MHz/spectral_data_11_00097.csv
# NMRfiles_Test/400MHz/spectral_data_16_00098.csv
# NMRfiles_Test/400MHz/spectral_data_05_00099.csv
# NMRfiles_Test/400MHz/spectral_data_15_00100.csv
# NMRfiles_Test/400MHz/spectral_data_10_00101.csv
# NMRfiles_Test/400MHz/spectral_data_09_00102.csv
# NMRfiles_Test/400MHz/spectral_data_15_00103.csv
# NMRfiles_Test/400MHz/spectral_data_09_00104.csv
# NMRfiles_Test/400MHz/spectral_data_08_00105.csv
# NMRfiles_Test/400MHz/spectral_data_05_00106.csv
# NMRfiles_Test/400MHz/spectral_data_09_00107.csv
# NMRfiles_Test/400MHz/spectral_data_05_00108.csv
# NMRfiles_Test/400MHz/spectral_data_07_00109.csv
# NMRfiles_Test/400MHz/spectral_data_12_00110.csv
# NMRfiles_Test/400MHz/spectral_data_12_00111.csv
# NMRfiles_Test/400MHz/spectral_data_10_00112.csv
# NMRfiles_Test/400MHz/spectral_data_12_00113.csv
# NMRfiles_Test/400MHz/spectral_data_08_00114.csv
# NMRfiles_Test/400MHz/spectral_data_11_00115.csv
# NMRfiles_Test/400MHz/spectral_data_08_00116.csv
# NMRfiles_Test/400MHz/spectral_data_07_00117.csv
# NMRfiles_Test/400MHz/spectral_data_06_00118.csv
# NMRfiles_Test/400MHz/spectral_data_12_00119.csv
# NMRfiles_Test/400MHz/spectral_data_10_00120.csv
# NMRfiles_Test/400MHz/spectral_data_08_00121.csv
# NMRfiles_Test/400MHz/spectral_data_15_00122.csv
# NMRfiles_Test/400MHz/spectral_data_06_00123.csv
# NMRfiles_Test/400MHz/spectral_data_13_00124.csv
# NMRfiles_Test/400MHz/spectral_data_13_00125.csv
# NMRfiles_Test/400MHz/spectral_data_06_00126.csv
# NMRfiles_Test/400MHz/spectral_data_14_00127.csv
# NMRfiles_Test/400MHz/spectral_data_10_00128.csv
# NMRfiles_Test/400MHz/spectral_data_14_00129.csv
# NMRfiles_Test/400MHz/spectral_data_09_00130.csv
# NMRfiles_Test/400MHz/spectral_data_16_00131.csv
# NMRfiles_Test/400MHz/spectral_data_15_00132.csv
# NMRfiles_Test/400MHz/spectral_data_16_00133.csv
# NMRfiles_Test/400MHz/spectral_data_07_00134.csv
# NMRfiles_Test/400MHz/spectral_data_05_00135.csv
# NMRfiles_Test/400MHz/spectral_data_15_00136.csv
# NMRfiles_Test/400MHz/spectral_data_07_00137.csv
# NMRfiles_Test/400MHz/spectral_data_10_00138.csv
# NMRfiles_Test/400MHz/spectral_data_16_00139.csv
# NMRfiles_Test/400MHz/spectral_data_13_00140.csv
# NMRfiles_Test/400MHz/spectral_data_12_00141.csv
# NMRfiles_Test/400MHz/spectral_data_05_00142.csv
# NMRfiles_Test/400MHz/spectral_data_13_00143.csv
# NMRfiles_Test/400MHz/spectral_data_16_00144.csv
# NMRfiles_Test/400MHz/spectral_data_06_00145.csv
# NMRfiles_Test/400MHz/spectral_data_05_00146.csv
# NMRfiles_Test/400MHz/spectral_data_13_00147.csv
# NMRfiles_Test/400MHz/spectral_data_05_00148.csv
# NMRfiles_Test/400MHz/spectral_data_09_00149.csv
# NMRfiles_Test/400MHz/spectral_data_14_00150.csv
# NMRfiles_Test/400MHz/spectral_data_14_00151.csv
# NMRfiles_Test/400MHz/spectral_data_05_00152.csv
# NMRfiles_Test/400MHz/spectral_data_11_00153.csv
# NMRfiles_Test/400MHz/spectral_data_13_00154.csv
# NMRfiles_Test/400MHz/spectral_data_05_00155.csv
# NMRfiles_Test/400MHz/spectral_data_06_00156.csv
# NMRfiles_Test/400MHz/spectral_data_13_00157.csv
# NMRfiles_Test/400MHz/spectral_data_09_00158.csv
# NMRfiles_Test/400MHz/spectral_data_13_00159.csv
# NMRfiles_Test/400MHz/spectral_data_09_00160.csv
# NMRfiles_Test/400MHz/spectral_data_09_00161.csv
# NMRfiles_Test/400MHz/spectral_data_12_00162.csv
# NMRfiles_Test/400MHz/spectral_data_14_00163.csv
# NMRfiles_Test/400MHz/spectral_data_07_00164.csv
# NMRfiles_Test/400MHz/spectral_data_15_00165.csv
# NMRfiles_Test/400MHz/spectral_data_10_00166.csv
# NMRfiles_Test/400MHz/spectral_data_13_00167.csv
# NMRfiles_Test/400MHz/spectral_data_12_00168.csv
# NMRfiles_Test/400MHz/spectral_data_16_00169.csv
# NMRfiles_Test/400MHz/spectral_data_12_00170.csv
# NMRfiles_Test/400MHz/spectral_data_07_00171.csv
# NMRfiles_Test/400MHz/spectral_data_11_00172.csv
# NMRfiles_Test/400MHz/spectral_data_13_00173.csv
# NMRfiles_Test/400MHz/spectral_data_08_00174.csv
# NMRfiles_Test/400MHz/spectral_data_11_00175.csv
# NMRfiles_Test/400MHz/spectral_data_14_00176.csv
# NMRfiles_Test/400MHz/spectral_data_14_00177.csv
# NMRfiles_Test/400MHz/spectral_data_12_00178.csv
# NMRfiles_Test/400MHz/spectral_data_16_00179.csv
# NMRfiles_Test/400MHz/spectral_data_13_00180.csv
# NMRfiles_Test/400MHz/spectral_data_09_00181.csv
# NMRfiles_Test/400MHz/spectral_data_16_00182.csv
# NMRfiles_Test/400MHz/spectral_data_09_00183.csv
# NMRfiles_Test/400MHz/spectral_data_06_00184.csv
# NMRfiles_Test/400MHz/spectral_data_11_00185.csv
# NMRfiles_Test/400MHz/spectral_data_07_00186.csv
# NMRfiles_Test/400MHz/spectral_data_12_00187.csv
# NMRfiles_Test/400MHz/spectral_data_06_00188.csv
# NMRfiles_Test/400MHz/spectral_data_11_00189.csv
# NMRfiles_Test/400MHz/spectral_data_09_00190.csv
# NMRfiles_Test/400MHz/spectral_data_12_00191.csv
# NMRfiles_Test/400MHz/spectral_data_13_00192.csv
# NMRfiles_Test/400MHz/spectral_data_16_00193.csv
# NMRfiles_Test/400MHz/spectral_data_11_00194.csv
# NMRfiles_Test/400MHz/spectral_data_07_00195.csv
# NMRfiles_Test/400MHz/spectral_data_13_00196.csv
# NMRfiles_Test/400MHz/spectral_data_11_00197.csv
# NMRfiles_Test/400MHz/spectral_data_14_00198.csv
# NMRfiles_Test/400MHz/spectral_data_14_00199.csv
# 10.671752452850342

# %% [markdown]
# We will need to do a) Hyperparameter search for machine learning model, irrespective of the model that we end up choosing; b) explore different encoding/decoding ML frameworks (CNN, ANN, etc);

# %%
import pandas as pd

# %%
df_test = pd.read_csv('./NMRfiles_Test/spectral_data_05_00001.csv')
df_test
# Out:
#       Unnamed: 0  400MHz_ppm  400MHz_intensity  60MHz_ppm  60MHz_intensity
# 0              0   -0.500000          0.000005  -0.500000         0.000222
# 1              1   -0.498000          0.000005  -0.498000         0.000224
# 2              2   -0.495999          0.000005  -0.495999         0.000225
# 3              3   -0.493999          0.000005  -0.493999         0.000226
# 4              4   -0.491999          0.000005  -0.491999         0.000228
# ...          ...         ...               ...        ...              ...
# 5495        5495   10.491999          0.000002  10.491999         0.000084
# 5496        5496   10.493999          0.000002  10.493999         0.000084
# 5497        5497   10.495999          0.000002  10.495999         0.000083
# 5498        5498   10.498000          0.000002  10.498000         0.000083
# 5499        5499   10.500000          0.000002  10.500000         0.000083
#
# [5500 rows x 5 columns]
