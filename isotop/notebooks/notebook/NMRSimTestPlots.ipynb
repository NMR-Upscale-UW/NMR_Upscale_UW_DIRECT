# %%
import nmrsim
from nmrsim import plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./Spectral_Data/spectral_data/400MHz/spectral_data_05_00006.csv')
df_60 = df[['60MHz_ppm', '60MHz_intensity']]
df_400 = df[['400MHz_ppm', '400MHz_intensity']]

# %%
nmrsim.plt.mplplot_lineshape(df_60['60MHz_ppm'], df_60['60MHz_intensity'], limits=(-0.5, 10.5))
# Out:
# (0       -0.500000
#  1       -0.498000
#  2       -0.495999
#  3       -0.493999
#  4       -0.491999
#            ...
#  5495    10.491999
#  5496    10.493999
#  5497    10.495999
#  5498    10.498000
#  5499    10.500000
#  Name: 60MHz_ppm, Length: 5500, dtype: float64,
#  0       0.000159
#  1       0.000160
#  2       0.000161
#  3       0.000163
#  4       0.000164
#            ...
#  5495    0.000065
#  5496    0.000064
#  5497    0.000064
#  5498    0.000064
#  5499    0.000064
#  Name: 60MHz_intensity, Length: 5500, dtype: float64)

# %%
nmrsim.plt.mplplot_lineshape(df_400['400MHz_ppm'], df_400['400MHz_intensity'], limits=(-0.5, 10.5))
# Out:
# (0       -0.500000
#  1       -0.498000
#  2       -0.495999
#  3       -0.493999
#  4       -0.491999
#            ...
#  5495    10.491999
#  5496    10.493999
#  5497    10.495999
#  5498    10.498000
#  5499    10.500000
#  Name: 400MHz_ppm, Length: 5500, dtype: float64,
#  0       0.000004
#  1       0.000004
#  2       0.000004
#  3       0.000004
#  4       0.000004
#            ...
#  5495    0.000001
#  5496    0.000001
#  5497    0.000001
#  5498    0.000001
#  5499    0.000001
#  Name: 400MHz_intensity, Length: 5500, dtype: float64)
