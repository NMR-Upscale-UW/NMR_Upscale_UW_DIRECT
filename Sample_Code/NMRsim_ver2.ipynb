# %%
import matplotlib.pyplot as plt
from nmrsim import Multiplet
from random import randint, uniform
import pandas

# %%
def NMR_Signal_Generator(spectrometer_frequencies):
    integral = randint(1,4)
    linewidth_hz = 2
    chemical_shift = uniform(0.5,9)
    coupling = uniform(3,15)
    multiplicity = randint(0,5)
    signals_list = [(Multiplet(chemical_shift * frequency, integral, [(coupling,multiplicity)], linewidth_hz)) for frequency in spectrometer_frequencies]
    return signals_list

# %%
def create_random_spectra(num_peaks):
    spectrometer_frequencies = [400,60]
    spectral_data = pandas.DataFrame(columns=['400MHz', '60MHz'])
    
    for i in range(0,num_peaks):
        signals_list = NMR_Signal_Generator(spectrometer_frequencies)
        spectral_data.loc[len(spectral_data)] = signals_list

    spectrum_400MHz = Multiplet(0,0.5,[],2) 
    for multiplet in spectral_data['400MHz']:
        spectrum_400MHz += multiplet

    spectrum_60MHz = Multiplet(0,0.5,[],2)
    for multiplet in spectral_data['60MHz']:
        spectrum_60MHz += multiplet
    
    spectrum_400MHz.vmin = -0.5 * spectrometer_frequencies[0]
    spectrum_400MHz.vmax = 10.5 * spectrometer_frequencies[0]
    x_400, y_400 = spectrum_400MHz.lineshape(points=5500)

    spectrum_60MHz.vmin = -0.5 * spectrometer_frequencies[1]
    spectrum_60MHz.vmax = 10.5 * spectrometer_frequencies[1]
    x_60, y_60 = spectrum_60MHz.lineshape(points=5500)

    return x_400, y_400, x_60, y_60

# %%
def write_nmr_spectra(index, num_peaks, x_400, y_400, x_60, y_60):
    # Saving data to file
    sf = [400,60]
    x_ppm_400 = x_400/sf[0]
    x_ppm_60 = x_60/sf[1]
    spectral_data = pandas.DataFrame(columns=['400MHz_ppm','400MHz_intensity', '60MHz_ppm','60MHz_intensity'])
    spectral_data['400MHz_ppm'] = x_ppm_400
    spectral_data['400MHz_intensity'] = y_400
    spectral_data['60MHz_ppm'] = x_ppm_60
    spectral_data['60MHz_intensity'] = y_60
    filename="NMRfiles_Test/"+"spectral_data_"+ str(num_peaks).zfill(2)+ "_" +str(index).zfill(5)+".csv"
    print(filename)
    spectral_data.to_csv(filename)

# %%
# num_peaks = Number of Peaks that you want in your spectra
# j = how many spectra do you want.

for j in range (0,200):
    num_peaks = randint(5,16)
    print(num_peaks)
    x_400, y_400, x_60, y_60 = create_random_spectra(num_peaks)
    write_nmr_spectra(j, num_peaks, x_400, y_400, x_60, y_60)
# Out:
# 5
# NMRfiles_Test/spectral_data_05_00000.csv
# 12
# NMRfiles_Test/spectral_data_12_00001.csv
# 7
# NMRfiles_Test/spectral_data_07_00002.csv
# 6
# NMRfiles_Test/spectral_data_06_00003.csv
# 13
# NMRfiles_Test/spectral_data_13_00004.csv
# 9
# NMRfiles_Test/spectral_data_09_00005.csv
# 14
# NMRfiles_Test/spectral_data_14_00006.csv
# 16
# NMRfiles_Test/spectral_data_16_00007.csv
# 5
# NMRfiles_Test/spectral_data_05_00008.csv
# 10
# NMRfiles_Test/spectral_data_10_00009.csv
# 8
# NMRfiles_Test/spectral_data_08_00010.csv
# 10
# NMRfiles_Test/spectral_data_10_00011.csv
# 5
# NMRfiles_Test/spectral_data_05_00012.csv
# 8
# NMRfiles_Test/spectral_data_08_00013.csv
# 11
# NMRfiles_Test/spectral_data_11_00014.csv
# 12
# NMRfiles_Test/spectral_data_12_00015.csv
# 11
# NMRfiles_Test/spectral_data_11_00016.csv
# 14
# NMRfiles_Test/spectral_data_14_00017.csv
# 7
# NMRfiles_Test/spectral_data_07_00018.csv
# 12
# NMRfiles_Test/spectral_data_12_00019.csv
# 5
# NMRfiles_Test/spectral_data_05_00020.csv
# 11
# NMRfiles_Test/spectral_data_11_00021.csv
# 9
# NMRfiles_Test/spectral_data_09_00022.csv
# 9
# NMRfiles_Test/spectral_data_09_00023.csv
# 11
# NMRfiles_Test/spectral_data_11_00024.csv
# 9
# NMRfiles_Test/spectral_data_09_00025.csv
# 9
# NMRfiles_Test/spectral_data_09_00026.csv
# 14
# NMRfiles_Test/spectral_data_14_00027.csv
# 11
# NMRfiles_Test/spectral_data_11_00028.csv
# 8
# NMRfiles_Test/spectral_data_08_00029.csv
# 12
# NMRfiles_Test/spectral_data_12_00030.csv
# 10
# NMRfiles_Test/spectral_data_10_00031.csv
# 13
# NMRfiles_Test/spectral_data_13_00032.csv
# 11
# NMRfiles_Test/spectral_data_11_00033.csv
# 13
# NMRfiles_Test/spectral_data_13_00034.csv
# 15
# NMRfiles_Test/spectral_data_15_00035.csv
# 13
# NMRfiles_Test/spectral_data_13_00036.csv
# 6
# NMRfiles_Test/spectral_data_06_00037.csv
# 9
# NMRfiles_Test/spectral_data_09_00038.csv
# 8
# NMRfiles_Test/spectral_data_08_00039.csv
# 12
# NMRfiles_Test/spectral_data_12_00040.csv
# 10
# NMRfiles_Test/spectral_data_10_00041.csv
# 15
# NMRfiles_Test/spectral_data_15_00042.csv
# 8
# NMRfiles_Test/spectral_data_08_00043.csv
# 9
# NMRfiles_Test/spectral_data_09_00044.csv
# 11
# NMRfiles_Test/spectral_data_11_00045.csv
# 12
# NMRfiles_Test/spectral_data_12_00046.csv
# 11
# NMRfiles_Test/spectral_data_11_00047.csv
# 5
# NMRfiles_Test/spectral_data_05_00048.csv
# 10
# NMRfiles_Test/spectral_data_10_00049.csv
# 11
# NMRfiles_Test/spectral_data_11_00050.csv
# 11
# NMRfiles_Test/spectral_data_11_00051.csv
# 13
# NMRfiles_Test/spectral_data_13_00052.csv
# 12
# NMRfiles_Test/spectral_data_12_00053.csv
# 6
# NMRfiles_Test/spectral_data_06_00054.csv
# 5
# NMRfiles_Test/spectral_data_05_00055.csv
# 7
# NMRfiles_Test/spectral_data_07_00056.csv
# 8
# NMRfiles_Test/spectral_data_08_00057.csv
# 7
# NMRfiles_Test/spectral_data_07_00058.csv
# 14
# NMRfiles_Test/spectral_data_14_00059.csv
# 16
# NMRfiles_Test/spectral_data_16_00060.csv
# 15
# NMRfiles_Test/spectral_data_15_00061.csv
# 14
# NMRfiles_Test/spectral_data_14_00062.csv
# 16
# NMRfiles_Test/spectral_data_16_00063.csv
# 7
# NMRfiles_Test/spectral_data_07_00064.csv
# 16
# NMRfiles_Test/spectral_data_16_00065.csv
# 15
# NMRfiles_Test/spectral_data_15_00066.csv
# 7
# NMRfiles_Test/spectral_data_07_00067.csv
# 9
# NMRfiles_Test/spectral_data_09_00068.csv
# 15
# NMRfiles_Test/spectral_data_15_00069.csv
# 8
# NMRfiles_Test/spectral_data_08_00070.csv
# 16
# NMRfiles_Test/spectral_data_16_00071.csv
# 12
# NMRfiles_Test/spectral_data_12_00072.csv
# 6
# NMRfiles_Test/spectral_data_06_00073.csv
# 6
# NMRfiles_Test/spectral_data_06_00074.csv
# 11
# NMRfiles_Test/spectral_data_11_00075.csv
# 12
# NMRfiles_Test/spectral_data_12_00076.csv
# 16
# NMRfiles_Test/spectral_data_16_00077.csv
# 10
# NMRfiles_Test/spectral_data_10_00078.csv
# 11
# NMRfiles_Test/spectral_data_11_00079.csv
# 14
# NMRfiles_Test/spectral_data_14_00080.csv
# 7
# NMRfiles_Test/spectral_data_07_00081.csv
# 6
# NMRfiles_Test/spectral_data_06_00082.csv
# 10
# NMRfiles_Test/spectral_data_10_00083.csv
# 10
# NMRfiles_Test/spectral_data_10_00084.csv
# 13
# NMRfiles_Test/spectral_data_13_00085.csv
# 16
# NMRfiles_Test/spectral_data_16_00086.csv
# 11
# NMRfiles_Test/spectral_data_11_00087.csv
# 11
# NMRfiles_Test/spectral_data_11_00088.csv
# 10
# NMRfiles_Test/spectral_data_10_00089.csv
# 9
# NMRfiles_Test/spectral_data_09_00090.csv
# 10
# NMRfiles_Test/spectral_data_10_00091.csv
# 8
# NMRfiles_Test/spectral_data_08_00092.csv
# 15
# NMRfiles_Test/spectral_data_15_00093.csv
# 5
# NMRfiles_Test/spectral_data_05_00094.csv
# 5
# NMRfiles_Test/spectral_data_05_00095.csv
# 6
# NMRfiles_Test/spectral_data_06_00096.csv
# 14
# NMRfiles_Test/spectral_data_14_00097.csv
# 16
# NMRfiles_Test/spectral_data_16_00098.csv
# 12
# NMRfiles_Test/spectral_data_12_00099.csv
# 8
# NMRfiles_Test/spectral_data_08_00100.csv
# 15
# NMRfiles_Test/spectral_data_15_00101.csv
# 9
# NMRfiles_Test/spectral_data_09_00102.csv
# 14
# NMRfiles_Test/spectral_data_14_00103.csv
# 5
# NMRfiles_Test/spectral_data_05_00104.csv
# 10
# NMRfiles_Test/spectral_data_10_00105.csv
# 15
# NMRfiles_Test/spectral_data_15_00106.csv
# 6
# NMRfiles_Test/spectral_data_06_00107.csv
# 9
# NMRfiles_Test/spectral_data_09_00108.csv
# 15
# NMRfiles_Test/spectral_data_15_00109.csv
# 15
# NMRfiles_Test/spectral_data_15_00110.csv
# 11
# NMRfiles_Test/spectral_data_11_00111.csv
# 6
# NMRfiles_Test/spectral_data_06_00112.csv
# 5
# NMRfiles_Test/spectral_data_05_00113.csv
# 11
# NMRfiles_Test/spectral_data_11_00114.csv
# 10
# NMRfiles_Test/spectral_data_10_00115.csv
# 6
# NMRfiles_Test/spectral_data_06_00116.csv
# 13
# NMRfiles_Test/spectral_data_13_00117.csv
# 6
# NMRfiles_Test/spectral_data_06_00118.csv
# 5
# NMRfiles_Test/spectral_data_05_00119.csv
# 10
# NMRfiles_Test/spectral_data_10_00120.csv
# 6
# NMRfiles_Test/spectral_data_06_00121.csv
# 7
# NMRfiles_Test/spectral_data_07_00122.csv
# 10
# NMRfiles_Test/spectral_data_10_00123.csv
# 13
# NMRfiles_Test/spectral_data_13_00124.csv
# 13
# NMRfiles_Test/spectral_data_13_00125.csv
# 7
# NMRfiles_Test/spectral_data_07_00126.csv
# 13
# NMRfiles_Test/spectral_data_13_00127.csv
# 6
# NMRfiles_Test/spectral_data_06_00128.csv
# 13
# NMRfiles_Test/spectral_data_13_00129.csv
# 13
# NMRfiles_Test/spectral_data_13_00130.csv
# 16
# NMRfiles_Test/spectral_data_16_00131.csv
# 8
# NMRfiles_Test/spectral_data_08_00132.csv
# 5
# NMRfiles_Test/spectral_data_05_00133.csv
# 10
# NMRfiles_Test/spectral_data_10_00134.csv
# 10
# NMRfiles_Test/spectral_data_10_00135.csv
# 10
# NMRfiles_Test/spectral_data_10_00136.csv
# 5
# NMRfiles_Test/spectral_data_05_00137.csv
# 6
# NMRfiles_Test/spectral_data_06_00138.csv
# 7
# NMRfiles_Test/spectral_data_07_00139.csv
# 8
# NMRfiles_Test/spectral_data_08_00140.csv
# 16
# NMRfiles_Test/spectral_data_16_00141.csv
# 16
# NMRfiles_Test/spectral_data_16_00142.csv
# 7
# NMRfiles_Test/spectral_data_07_00143.csv
# 14
# NMRfiles_Test/spectral_data_14_00144.csv
# 13
# NMRfiles_Test/spectral_data_13_00145.csv
# 11
# NMRfiles_Test/spectral_data_11_00146.csv
# 13
# NMRfiles_Test/spectral_data_13_00147.csv
# 6
# NMRfiles_Test/spectral_data_06_00148.csv
# 16
# NMRfiles_Test/spectral_data_16_00149.csv
# 14
# NMRfiles_Test/spectral_data_14_00150.csv
# 13
# NMRfiles_Test/spectral_data_13_00151.csv
# 7
# NMRfiles_Test/spectral_data_07_00152.csv
# 16
# NMRfiles_Test/spectral_data_16_00153.csv
# 7
# NMRfiles_Test/spectral_data_07_00154.csv
# 5
# NMRfiles_Test/spectral_data_05_00155.csv
# 11
# NMRfiles_Test/spectral_data_11_00156.csv
# 5
# NMRfiles_Test/spectral_data_05_00157.csv
# 15
# NMRfiles_Test/spectral_data_15_00158.csv
# 8
# NMRfiles_Test/spectral_data_08_00159.csv
# 14
# NMRfiles_Test/spectral_data_14_00160.csv
# 13
# NMRfiles_Test/spectral_data_13_00161.csv
# 15
# NMRfiles_Test/spectral_data_15_00162.csv
# 16
# NMRfiles_Test/spectral_data_16_00163.csv
# 9
# NMRfiles_Test/spectral_data_09_00164.csv
# 13
# NMRfiles_Test/spectral_data_13_00165.csv
# 9
# NMRfiles_Test/spectral_data_09_00166.csv
# 14
# NMRfiles_Test/spectral_data_14_00167.csv
# 7
# NMRfiles_Test/spectral_data_07_00168.csv
# 13
# NMRfiles_Test/spectral_data_13_00169.csv
# 10
# NMRfiles_Test/spectral_data_10_00170.csv
# 11
# NMRfiles_Test/spectral_data_11_00171.csv
# 7
# NMRfiles_Test/spectral_data_07_00172.csv
# 10
# NMRfiles_Test/spectral_data_10_00173.csv
# 14
# NMRfiles_Test/spectral_data_14_00174.csv
# 10
# NMRfiles_Test/spectral_data_10_00175.csv
# 16
# NMRfiles_Test/spectral_data_16_00176.csv
# 16
# NMRfiles_Test/spectral_data_16_00177.csv
# 8
# NMRfiles_Test/spectral_data_08_00178.csv
# 7
# NMRfiles_Test/spectral_data_07_00179.csv
# 16
# NMRfiles_Test/spectral_data_16_00180.csv
# 12
# NMRfiles_Test/spectral_data_12_00181.csv
# 6
# NMRfiles_Test/spectral_data_06_00182.csv
# 9
# NMRfiles_Test/spectral_data_09_00183.csv
# 9
# NMRfiles_Test/spectral_data_09_00184.csv
# 9
# NMRfiles_Test/spectral_data_09_00185.csv
# 7
# NMRfiles_Test/spectral_data_07_00186.csv
# 6
# NMRfiles_Test/spectral_data_06_00187.csv
# 14
# NMRfiles_Test/spectral_data_14_00188.csv
# 15
# NMRfiles_Test/spectral_data_15_00189.csv
# 5
# NMRfiles_Test/spectral_data_05_00190.csv
# 9
# NMRfiles_Test/spectral_data_09_00191.csv
# 10
# NMRfiles_Test/spectral_data_10_00192.csv
# 8
# NMRfiles_Test/spectral_data_08_00193.csv
# 7
# NMRfiles_Test/spectral_data_07_00194.csv
# 13
# NMRfiles_Test/spectral_data_13_00195.csv
# 11
# NMRfiles_Test/spectral_data_11_00196.csv
# 14
# NMRfiles_Test/spectral_data_14_00197.csv
# 7
# NMRfiles_Test/spectral_data_07_00198.csv
# 5
# NMRfiles_Test/spectral_data_05_00199.csv

# %% [markdown]
# Talk to Lauren How to Connect DREN to HyperThought/ELSZ for keeping the data and either developing ML codes here in VS Code or on Google Collab.
#
# We will need to do a) Hyperparameter search for machine learning model, irrespective of the model that we end up choosing; b) explore different encoding/decoding ML frameworks (CNN, ANN, etc);
